-- %% [markdown]
-- # [dbo].[Contactos]

-- %%
USE [agenda_personal]
GO

-- %%
/****** Object:  Table [dbo].[Contactos]    Script Date: 24/10/2023 13:38:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Contactos](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NombreCompleto] [nvarchar](255) NOT NULL,
	[NumeroDocumento] [nvarchar](20) NOT NULL,
	[Direccion] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Correos]

-- %%
/****** Object:  Table [dbo].[Correos]    Script Date: 24/10/2023 13:38:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Correos](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Direccion] [nvarchar](100) NOT NULL,
	[ContactoID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Telefonos]

-- %%
/****** Object:  Table [dbo].[Telefonos]    Script Date: 24/10/2023 13:38:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Telefonos](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Numero] [nvarchar](20) NOT NULL,
	[ContactoID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Correos__Contact__3C69FB99]

-- %%
ALTER TABLE [dbo].[Correos]  WITH CHECK ADD FOREIGN KEY([ContactoID])
REFERENCES [dbo].[Contactos] ([ID])
GO

-- %% [markdown]
-- # [FK__Telefonos__Conta__398D8EEE]

-- %%
ALTER TABLE [dbo].[Telefonos]  WITH CHECK ADD FOREIGN KEY([ContactoID])
REFERENCES [dbo].[Contactos] ([ID])
GO
